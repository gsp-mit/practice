# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.utils import shuffle
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import pickle
import seaborn as sns

# %%
df=pd.read_csv("imports-85.data")

# %%
df.columns=["symboling" ,"normalized-losses","make",  "fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size",            
  "fuel-system",
 "bore",           
 "stroke",                   
  "compression-ratio",       
  "horsepower",              
 "peak-rpm",               
  "city-mpg",                
  "highway-mpg",              
  "price"  ]
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.dropna(how='any')
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.replace('[?]', np.nan, regex=True, inplace=True)
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            1               NaN  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               NaN         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 199         -1                95        volvo       gas        std
# 200         -1                95        volvo       gas      turbo
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo    diesel      turbo
# 203         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    40
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df.dropna(how='any',inplace=True)
# df.drop(['index'],axis=1,inplace=True).reset_index()
df.reset_index()
# Out:
#      index  symboling normalized-losses   make fuel-type aspiration  \
# 0        2          2               164   audi       gas        std
# 1        3          2               164   audi       gas        std
# 2        5          1               158   audi       gas        std
# 3        7          1               158   audi       gas      turbo
# 4        9          2               192    bmw       gas        std
# ..     ...        ...               ...    ...       ...        ...
# 154    199         -1                95  volvo       gas        std
# 155    200         -1                95  volvo       gas      turbo
# 156    201         -1                95  volvo       gas        std
# 157    202         -1                95  volvo    diesel      turbo
# 158    203         -1                95  volvo       gas      turbo
#
#     num-of-doors body-style drive-wheels engine-location  ...  engine-size  \
# ...

# %%
df.duplicated().sum(), df.isnull().sum()
# Out:
# (0,
#  symboling            0
#  normalized-losses    0
#  make                 0
#  fuel-type            0
#  aspiration           0
#  num-of-doors         0
#  body-style           0
#  drive-wheels         0
#  engine-location      0
#  wheel-base           0
#  length               0
#  width                0
#  height               0
#  curb-weight          0
#  engine-type          0
#  num-of-cylinders     0
#  engine-size          0
#  fuel-system          0
#  bore                 0
#  stroke               0
#  compression-ratio    0
#  horsepower           0
#  peak-rpm             0
#  city-mpg             0
#  highway-mpg          0
#  price                0
#  dtype: int64)

# %%
df=df.drop('drive-wheels',axis=1)
df
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 2            2               164   audi       gas        std         four
# 3            2               164   audi       gas        std         four
# 5            1               158   audi       gas        std         four
# 7            1               158   audi       gas      turbo         four
# 9            2               192    bmw       gas        std          two
# ..         ...               ...    ...       ...        ...          ...
# 199         -1                95  volvo       gas        std         four
# 200         -1                95  volvo       gas      turbo         four
# 201         -1                95  volvo       gas        std         four
# 202         -1                95  volvo    diesel      turbo         four
# 203         -1                95  volvo       gas      turbo         four
#
#     body-style engine-location  wheel-base  length  ...  engine-size  \
# ...

# %%
df=pd.get_dummies(df,columns=['make','fuel-type','aspiration','num-of-doors','body-style','engine-location','fuel-system','engine-type','num-of-cylinders'])

# %%
df
# Out:
#      symboling normalized-losses  wheel-base  length  width  height  \
# 2            2               164        99.8   176.6   66.2    54.3
# 3            2               164        99.4   176.6   66.4    54.3
# 5            1               158       105.8   192.7   71.4    55.7
# 7            1               158       105.8   192.7   71.4    55.9
# 9            2               192       101.2   176.8   64.8    54.3
# ..         ...               ...         ...     ...    ...     ...
# 199         -1                95       109.1   188.8   68.9    55.5
# 200         -1                95       109.1   188.8   68.8    55.5
# 201         -1                95       109.1   188.8   68.9    55.5
# 202         -1                95       109.1   188.8   68.9    55.5
# 203         -1                95       109.1   188.8   68.9    55.5
#
#      curb-weight  engine-size  bore stroke  ...  engine-type_dohc  \
# 2           2337          109  3.19   3.40  ...                 0
# ...

# %%
df['price']=pd.to_numeric(df['price'])
df['stroke']=pd.to_numeric(df['stroke'])
df['normalized-losses']=pd.to_numeric(df['normalized-losses'])
df['bore']=pd.to_numeric(df['bore'])
df['horsepower']=pd.to_numeric(df['horsepower'])
df['peak-rpm']=pd.to_numeric(df['peak-rpm'])
mean , std= df.price.mean(), df.price.std()
upper= mean + (2*std)
lower=mean -(2*std)
upper , lower
# Out:
# (19606.116862961528, 1645.3831370384723)

# %%
df= df[(df.price<upper)].reset_index()
df.drop(['index'],axis=1,inplace=True)
df
# Out:
#      level_0  symboling  normalized-losses  wheel-base  length  width  height  \
# 0          0          2                164        99.8   176.6   66.2    54.3
# 1          1          2                164        99.4   176.6   66.4    54.3
# 2          2          1                158       105.8   192.7   71.4    55.7
# 3          3          2                192       101.2   176.8   64.8    54.3
# 4          4          0                192       101.2   176.8   64.8    54.3
# ..       ...        ...                ...         ...     ...    ...     ...
# 140      144         -1                 74       104.3   188.8   67.2    57.5
# 141      145         -2                103       104.3   188.8   67.2    56.2
# 142      146         -1                 74       104.3   188.8   67.2    57.5
# 143      147         -1                 95       109.1   188.8   68.9    55.5
# 144      148         -1                 95       109.1   188.8   68.8    55.5
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 63 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   level_0                 145 non-null    int64
#  1   symboling               145 non-null    int64
#  2   normalized-losses       145 non-null    int64
#  3   wheel-base              145 non-null    float64
#  4   length                  145 non-null    float64
#  5   width                   145 non-null    float64
#  6   height                  145 non-null    float64
#  7   curb-weight             145 non-null    int64
#  8   engine-size             145 non-null    int64
#  9   bore                    145 non-null    float64
#  10  stroke                  145 non-null    float64
#  11  compression-ratio       145 non-null    float64
#  12  horsepower              145 non-null    int64
#  13  peak-rpm                145 non-null    int64
# ...

# %%
X=df.drop('price',axis=1)
y=df['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=42)

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
acc=lr.score(X_test,y_test)
acc
# Out:
# 0.8432014904335083

# %%
prediction=lr.predict(X_test)
prediction
# Out:
# array([19981.15783293, 14608.26250369,  9809.16498042,  7393.78846016,
#         5769.84841138, 10919.53856255, 15592.74489342,  8222.19236497,
#        17465.16458879,  8912.45416222,  7452.27508205,  6916.58320065,
#        14574.5864111 ,  7253.65345083, 17211.50862266])

# %%
data=pd.read_csv('weather.data', parse_dates=['day'])

# %%
data
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
 data.set_index('day')
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=data.fillna(0)
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          0.0        9.0   Sunny
# 2 2017-01-05         28.0        0.0    Snow
# 3 2017-01-06          0.0        7.0       0
# 4 2017-01-07         32.0        0.0    Rain
# 5 2017-01-08          0.0        0.0   Sunny
# 6 2017-01-09          0.0        0.0       0
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=data.fillna({
    'temperature': 0,
    'windspeed': 0,
    'event':'no-event'
})
new_df
# Out:
#          day  temperature  windspeed     event
# 0 2017-01-01         32.0        6.0      Rain
# 1 2017-01-04          0.0        9.0     Sunny
# 2 2017-01-05         28.0        0.0      Snow
# 3 2017-01-06          0.0        7.0  no-event
# 4 2017-01-07         32.0        0.0      Rain
# 5 2017-01-08          0.0        0.0     Sunny
# 6 2017-01-09          0.0        0.0  no-event
# 7 2017-01-10         34.0        8.0    Cloudy
# 8 2017-01-11         40.0       12.0     Sunny

# %%
new_df=data.fillna(method='ffill')

# %%
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        9.0    Snow
# 3 2017-01-06         28.0        7.0    Snow
# 4 2017-01-07         32.0        7.0    Rain
# 5 2017-01-08         32.0        7.0   Sunny
# 6 2017-01-09         32.0        7.0   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=data.fillna(method='bfill')

# %%
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         28.0        9.0   Sunny
# 2 2017-01-05         28.0        7.0    Snow
# 3 2017-01-06         32.0        7.0    Rain
# 4 2017-01-07         32.0        8.0    Rain
# 5 2017-01-08         34.0        8.0   Sunny
# 6 2017-01-09         34.0        8.0  Cloudy
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
new_df=data.interpolate()

# %%
new_df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01    32.000000       6.00    Rain
# 1 2017-01-04    30.000000       9.00   Sunny
# 2 2017-01-05    28.000000       8.00    Snow
# 3 2017-01-06    30.000000       7.00     NaN
# 4 2017-01-07    32.000000       7.25    Rain
# 5 2017-01-08    32.666667       7.50   Sunny
# 6 2017-01-09    33.333333       7.75     NaN
# 7 2017-01-10    34.000000       8.00  Cloudy
# 8 2017-01-11    40.000000      12.00   Sunny

# %%
new_df=data.interpolate(method='time')
new_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-7cffa2a749df> in <module>
# ----> 1 new_df=data.interpolate(method='time')
#       2 new_df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    6868                 "those NaNs before interpolating."
#    6869             )
# -> 6870         new_data = obj._mgr.interpolate(
#    6871             method=method,
#    6872             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     559
#     560     def interpolate(self, **kwargs) -> "BlockManager":
# --> 561         return self.apply("interpolate", **kwargs)
#     562
#     563     def shift(self, periods: int, axis: int, fill_value) -> "BlockManager":
#
# ...

# %%
df_1=data.dropna()

# %%
df_1

# %%
df_1=data.dropna(axis=1)

# %%
df_1

# %%
df_1=data.dropna(how='all')

# %%
df_1

# %%
df_1=data.dropna(how='any')
df_1

# %%
df_1=data.dropna(thresh=2)
df_1

# %%
df=data.interpolate(method='time',inplace=True)
df=data.fillna({
    'event':'none'
})
df

# %%
from sklearn.preprocessing import LabelEncoder
lin=LabelEncoder()
df['event']=lin.fit_transform(list(df['event']))
df

# %%
df.set_index(np.arange(9),inplace=True)
df['date']=data['day']
df

# %%
df.groupby(['temperature'])['event'].mean().reset_index()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_theme(style='darkgrid')
plt.figure(figsize=(10,60))
sns.barplot(y='temperature',x='date',hue='event',data=df)
plt.show()

# %%
df_2=pd.DataFrame({
    'score':['exceptional','average','good','poor','average','exceptional'],
    'student':['rob','maya','parthiv','tom','julian','erica']
})
df_2

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder()

# %%
df_2['score']=ohe.transform(list(df['score']))
